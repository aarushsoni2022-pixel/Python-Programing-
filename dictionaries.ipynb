# %%
car_dict={'brand':"BMW","model":"x5","year":2023}
print(car_dict)
# Out:
# {'brand': 'BMW', 'model': 'x5', 'year': 2023}

# %%
#accessing dictionary items
print(car_dict['brand'])
# Out:
# BMW

# %%
#lenght of dict
print(len(car_dict))
# Out:
# 3

# %%
#types of data
print(type(car_dict))
# Out:
# <class 'dict'>

# %%
#for duplicate keys 
car_dict2={'brand':"BMW","model":"x5","year":2023,"year":2025}

# %%
car_dict2
# Out:
# {'brand': 'BMW', 'model': 'x5', 'year': 2025}

# %%
x=car_dict.get("brand")

# %%
x
# Out:
# 'BMW'

# %%
#the key() method will retuen a list of all the key in the dictionary 
car_dict.keys()
# Out:
# dict_keys(['brand', 'model', 'year'])

# %%
#the key() method will retuen a list of all the values in the dictionary 
car_dict.values()
# Out:
# dict_values(['BMW', 'x5', 2023])

# %%
#to change the values of dictionary
car_dict["year"]=2014

# %%
car_dict
# Out:
# {'brand': 'BMW', 'model': 'x5', 'year': 2014}

# %%
#To add new key:values in dict
car_dict["color"]="white"

# %%
car_dict
# Out:
# {'brand': 'BMW', 'model': 'x5', 'year': 2014, 'color': 'white'}

# %%
#the values in dictionary items can be of any data type
d3={"name":"A","year":2023,"pass":True,"marks":[50,60,70]}

# %%
d3
# Out:
# {'name': 'A', 'year': 2023, 'pass': True, 'marks': [50, 60, 70]}

# %%
d3.update({"year":2222})

# %%
d3
# Out:
# {'name': 'A', 'year': 2222, 'pass': True, 'marks': [50, 60, 70]}

# %%
d3["ph_no"]=123456789

# %%
d3
# Out:
# {'name': 'A',
#  'year': 2222,
#  'pass': True,
#  'marks': [50, 60, 70],
#  'ph_no': 123456789}

# %%
d3.pop("ph_no")
# Out:
# 123456789

# %%
d3.popitem()
# Out:
# ('marks', [50, 60, 70])

# %%
d3.popitem()
# Out:
# ('pass', True)

# %%
d3.popitem()
# Out:
# ('year', 2222)

# %%
d3
# Out:
# {}

# %%
d3={"name":"A","year":2023,"pass":True,"marks":[50,60,70]}

# %%
d3
# Out:
# {'name': 'A', 'year': 2023, 'pass': True, 'marks': [50, 60, 70]}

# %%
del d3["marks"]

# %%
d3
# Out:
# {'name': 'A', 'year': 2023, 'pass': True}

# %%
#copy dictionary 
d4=d3.copy()

# %%
d4
# Out:
# {'name': 'A', 'year': 2023, 'pass': True}

# %%
d5=dict(d4)

# %%
d5
# Out:
# {'name': 'A', 'year': 2023, 'pass': True}

# %%
myfamily={
    "child1":{
        "name":"deep",
        "year":2024
    },
    "child2":{
        "name":"ravi",
        "year":2020
    },
    "child3":{
        "name":"balu",
        "year":2021
    },
}

# %%
myfamily
# Out:
# {'child1': {'name': 'deep', 'year': 2024},
#  'child2': {'name': 'ravi', 'year': 2020},
#  'child3': {'name': 'balu', 'year': 2021}}

# %%
print(myfamily["child2"]["name"])
# Out:
# ravi
