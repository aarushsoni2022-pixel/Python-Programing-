# %% [markdown]
# WORKBOOK OF PYTHON

# %%
print("welcome to aaft")
# Out:
# welcome to aaft

# %%
#variables

# %%
a=2
print(a)
# Out:
# 2

# %%
a=67
b=89
c=b-a
d=45
e=c+d
print(e)
# Out:
# 67

# %%
a=67
b=79
c=a*b
d=c+45
e=d-5
f=e/2

print(f)
# Out:
# 2666.5

# %%
#python is case sensitve

# %%
print("hello world")
# Out:
# hello world

# %%
x = 5
y = "aarush" 
print(x)
print(y)
# Out:
# 5
# aarush

# %%
#example of case sensitve

# %%
a=5
A="aarush"
print(a)
print(A)
# Out:
# 5
# aarush

# %%
#legal variable name 

myvar="shiv"
my_var="shiv"
_my_var="shiv"
MYVAR="SHIV"
myvar="shiv"

# %%
#illegal vcarible name 

"""
    my-var="shiv"
    #2myvar="shiv"
    my var="shiv
"""

#we cannot use slash,numbers in front of varible and space also
# Out:
# '\n    my-var="shiv"\n    #2myvar="shiv"\n    my var="shiv\n'

# %%
#many value to multiple varibles 
x,y,z="apple","orange","banana"
print(x,y,z)
# Out:
# apple orange banana

# %%
#or

# %%
# class types

# %%
#many value to multiple varibles 
x,y,z="apple","orange","banana"
print(x)
print(y)
print(z)
# Out:
# apple
# orange
# banana

# %%
#comments are important for better understanding

# %%
#addition of 2 numbers 
a=69
b=78
c=a+b
print(c)
# Out:
# 147

# %%
x= 3  #Int
y= 3.5 #float 
z=4+3j #complex

# %%
x=[1,2,3,4,5] #lists 
y=['a','b']   #lists

# %%
x=(1,2,3,4,5) #tuple
y=('a','b')   #tuple

# %%
d={'a':1,'b':2,'c':3} #dictionary

# %%
s={1,2,3} #sets

# %%
s1="hello" #string

# %%
#list creation 
l1=[1,2,3,4,5]
print(l1)
# Out:
# [1, 2, 3, 4, 5]

# %%
l1
# Out:
# [1, 2, 3, 4, 5]

# %%
#list access
l2=["a","b","c","d","e"]
l2[4]
# Out:
# 'e'

# %%
#range of indexes 
l2[1:4]
# Out:
# ['b', 'c', 'd']

# %%
l2[1:5]
# Out:
# ['b', 'c', 'd', 'e']

# %%
l2[1:4]
# Out:
# ['b', 'c', 'd']

# %%
l2[1:]
# Out:
# ['b', 'c', 'd', 'e']

# %%
l2[0:3]
# Out:
# ['a', 'b', 'c']

# %%
l2[:3]
# Out:
# ['a', 'b', 'c']

# %%
l2[4]

# %%
l2[3]
# Out:
# 'd'

# %%
#negative indexing

# %%
l2[-3:]
# Out:
# ['c', 'd', 'e']

# %%
l2[-5:-2]
# Out:
# ['a', 'b', 'c']

# %%
l2[:-3]
# Out:
# ['a', 'b']

# %%
l2[-5:]
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
l2[:-1]
# Out:
# ['a', 'b', 'c', 'd']

# %%
l2[1:3]="1","2"
print(l2)
# Out:
# ['a', '1', '2', 'd', 'e']

# %%
l2[1:3]="1","2"
print(l2)
# Out:
# ['a', '1', '2', 'd', 'e']

# %%
#sports list

# %%
ls=["cricket","hockey","volleyball","basketball","chess"]
print(ls)
# Out:
# ['cricket', 'hockey', 'volleyball', 'basketball', 'chess']

# %%
#Acess

# %%
ls[4]
# Out:
# 'chess'

# %%
ls[3]
# Out:
# 'basketball'

# %%
ls[0:3]
# Out:
# ['cricket', 'hockey', 'volleyball']

# %%
ls[:5]
# Out:
# ['cricket', 'hockey', 'volleyball', 'basketball', 'chess']

# %%
ls[-5:]
# Out:
# ['cricket', 'hockey', 'volleyball', 'basketball', 'chess']

# %%
ls[0:4]
# Out:
# ['cricket', 'hockey', 'volleyball', 'basketball']

# %%
ls[:-4]
# Out:
# ['cricket']

# %%
ls[-4:3]
# Out:
# ['hockey', 'volleyball']

# %%
lq=["yo","yo","honey","singh"]
print(lq)
# Out:
# ['yo', 'yo', 'honey', 'singh']

# %%
lq.append("?")
print(lq)
# Out:
# ['yo', 'yo', 'honey', 'singh', '?']

# %%
lq.remove("?")
print(lq)
# Out:
# ['yo', 'yo', 'honey', 'singh']

# %%
ly=["is a star"]
print(ly)
# Out:
# ['is a star']

# %%
lq.extend(ly)
print(lq)
# Out:
# ['yo', 'yo', 'honey', 'singh', 'is a star']

# %%
lt=["a","b","c","d"]
print(lt)
# Out:
# ['a', 'b', 'c', 'd']

# %%
lt.pop()
# Out:
# 'd'

# %%
lt
# Out:
# ['a', 'b', 'c']

# %%
lu=["a",1,"b",2,"c"]
del lu[3]

# %%
lu
# Out:
# ['a', 1, 'b', 'c']

# %%
car=["hilux","g63","range"]
print(car)
# Out:
# ['hilux', 'g63', 'range']

# %%
vehicle=car.copy()
print(vehicle)
# Out:
# ['hilux', 'g63', 'range']

# %%
l11=[1,2,3]
print(l11)
# Out:
# [1, 2, 3]

# %%
l12=[4,5,6]
print(l12)
# Out:
# [4, 5, 6]

# %%
l13=l11+l12

# %%
print(l13)
# Out:
# [1, 2, 3, 4, 5, 6]
