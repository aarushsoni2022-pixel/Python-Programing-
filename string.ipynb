# %% [markdown]
# STRING

# %%
print("hello world")
# Out:
# hello world

# %%
#python does not have character data type, a single character is simply a string with a length of1.
#square brackets can be used to access element of a string

# %%
a='hello world'

# %%
print(len(a))
# Out:
# 11

# %%
#access of elemnets 
b='hello,world!'

# %%
#slicing
print(b[2:5])
# Out:
# llo

# %%
#slice from the start 
b="hello,world!"
print(b[:5])
# Out:
# hello

# %%
#slice to the end 
b="hello,world!"
print(b[2:])
# Out:
# llo,world!

# %%
#neagtive indexing 
b="hello,world!"
print(b[-5:-2])
# Out:
# orl

# %%
#modify strings 
#python has a set of in built-methods that can be used in strings

# %%
a="hello,world!"
print(a.upper())
# Out:
# HELLO,WORLD!

# %%
a="hello,world!"
print(a.lower())
# Out:
# hello,world!

# %%
a=" hello,world! "
print(a.strip())
# Out:
# hello,world!

# %%
#string concatenation
# to concatenate, or ,combime, two strings you can use the +operator

# %%
a="hello "
b="world"
c=a+b
print(c)
# Out:
# hello world

# %%
#we can combime strings and numbers by using the format()method!
age=35
txt="my name is john and i am {}"
print(txt.format(age))
# Out:
# my name is john and i am 35

# %%
#the format ()method takes unlimited number of arguments and are placed into the respective place holders
quantity=4
item=567
price=45.89
myorder="i want {} pieces of item {} for {} dollars."
print(myorder.format(quantity,item,price))
# Out:
# i want 4 pieces of item 567 for 45.89 dollars.
