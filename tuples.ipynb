# %% [markdown]
# TUPLES

# %%
# Tuples are used to store multiple items in an single variable 
# A tuple is acollection which is orederd and unchangeable
# Tuple items are orderd,unchangeable

# %%
t1=(1,2,3,4,5)
print(t1)
# Out:
# (1, 2, 3, 4, 5)

# %%
print(type(t1))
# Out:
# <class 'tuple'>

# %%
t2=("a","b","c","d","e")
print(t2)
# Out:
# ('a', 'b', 'c', 'd', 'e')

# %%
t2[4]
# Out:
# 'e'

# %%
li=(4)
print(li)
print(type(li))
# Out:
# 4
# <class 'int'>

# %%
t=(1)
t
# Out:
# 1

# %%
type(t)
# Out:
# int

# %%
#creating tuple with one element 

ty=(1,)
print(ty)
# Out:
# (1,)

# %%
type(ty)
# Out:
# tuple

# %%
#access elements in tuple

# %%
t1=(1,2,3,4,5)
print(t1)
# Out:
# (1, 2, 3, 4, 5)

# %%
t1[3]
# Out:
# 4

# %%
t1[1:4]
# Out:
# (2, 3, 4)

# %%
t1[2:]
# Out:
# (3, 4, 5)

# %%
#crerating list or tuple in reverse 

t1[::-1]
# Out:
# (5, 4, 3, 2, 1)

# %%
#changing elements in tuple

# %%
t3=("a","b","c","d","e")
print(t3)
# Out:
# ('a', 'b', 'c', 'd', 'e')

# %%
y=list(t3)

# %%
print(type(y))
# Out:
# <class 'list'>

# %%
y
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
y[2]=11

# %%
print(y)
# Out:
# ['a', 'b', 11, 'd', 'e']

# %%
t3=tuple(y)

# %%
print(t3)
# Out:
# ('a', 'b', 11, 'd', 'e')

# %%
t3
# Out:
# ('a', 'b', 11, 'd', 'e')

# %%
t4=("a","b","c","d","e")
print(type(t4))
# Out:
# <class 'tuple'>

# %%
w=list(t4)

# %%
print(type(w))
# Out:
# <class 'list'>

# %%
w
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
w.append("f")
print(w)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']
